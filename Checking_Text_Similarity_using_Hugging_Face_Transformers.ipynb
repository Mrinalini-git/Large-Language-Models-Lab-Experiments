# %%
# !pip install -q transformers sentence-transformers

from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
sentence1 = input("Enter the first sentence.")
sentence2 = input("Enter the second sentence.")
embedding1 = model.encode(sentence1, convert_to_tensor=True)
embedding2 = model.encode(sentence2, convert_to_tensor=True)

# Calculate cosine similarity between the embeddings
cosine_similarity = util.cos_sim(embedding1, embedding2)

print(f"Sentence 1: {sentence1}")
print(f"Sentence 2: {sentence2}")
print(f"Similarity: {cosine_similarity.item():.4f}")

if cosine_similarity.item() > 0.5:
  print("The sentences are similar.")
else :
  print("The sentences are dissimilar.")
# Out:
# Enter the first sentence.Hello everybody!
# Enter the second sentence.Hi everyone!
# Sentence 1: Hello everybody!
# Sentence 2: Hi everyone!
# Similarity: 0.8508
# The sentences are similar.

# %%
sentence3 = input("Enter the first sentence.")
sentence4 = input("Enter the second sentence.")

embedding3 = model.encode(sentence3, convert_to_tensor=True)
embedding4 = model.encode(sentence4, convert_to_tensor=True)

cosine_similarity_dissimilar = util.cos_sim(embedding3, embedding4)

print(f"\nSentence 3: {sentence3}")
print(f"Sentence 4: {sentence4}")
print(f"Similarity: {cosine_similarity_dissimilar.item():.4f}")

if cosine_similarity_dissimilar.item() > 0.5:
  print("The sentences are similar.")
else :
  print("The sentences are dissimilar.")
# Out:
# Enter the first sentence.I like music.
# Enter the second sentence.The restaurant is closed.
#
# Sentence 3: I like music.
# Sentence 4: The restaurant is closed.
# Similarity: 0.0313
# The sentences are dissimilar.
